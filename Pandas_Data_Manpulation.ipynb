# %%
# import basic libraries
import numpy as np
import pandas as pd

# %%
# Load the data
data=pd.read_csv("customers-100.csv")

# %%
pwd
# Out:
# 'C:\\Users\\chand\\Downloads\\Machine learning Assosiate'

# %%
data
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %% [markdown]
# # Basic Checks

# %%
# Shape : It is used to find no of rows and no of columns in a data
data.shape
# Out:
# (100, 12)

# %%
# head - It is used toprint first 5 rows
data.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# tail - It is used to print last 5 rows
data.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
# print all the columns
data.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
# to check datatype of each column
data.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
# Describe : It is used to do statistical analysis
data.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
# Statistical analysis for categorical data
data.describe(include="object")
# Out:
#             Customer Id First Name Last Name    Company          City  \
# count               100        100       100        100           100
# unique              100         93        97         99           100
# top     DD37Cf93aecA6Dc     Sheryl     Greer  Simon LLC  East Leonard
# freq                  1          2         2          2             1
#
#                 Country       Phone 1           Phone 2  \
# count               100           100               100
# unique               85           100               100
# top     Solomon Islands  229.077.5154  397.884.0519x718
# freq                  4             1                 1
#
#                            Email Subscription Date                     Website
# count                        100               100                         100
# unique                       100                96                         100
# top     zunigavanessa@smith.info        2021-12-02  http://www.stephenson.com/
# ...

# %%
# fetch numerical column
data.select_dtypes(include=["int64","float64"])
# Out:
#     Index
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
#
# [100 rows x 1 columns]

# %%
data.select_dtypes(include=["int64","float64"]).columns
# Out:
# Index(['Index'], dtype='object')

# %%
# fetch categorical columns
data.select_dtypes(include="object").columns
# Out:
# Index(['Customer Id', 'First Name', 'Last Name', 'Company', 'City', 'Country',
#        'Phone 1', 'Phone 2', 'Email', 'Subscription Date', 'Website'],
#       dtype='object')

# %%
# unique : it is used to find unique categories in a data
data.Company.unique()
# Out:
# array(['Rasmussen Group', 'Vega-Gentry', 'Murillo-Perry',
#        'Dominguez, Mcmillan and Donovan', 'Martin, Lang and Andrade',
#        'Steele Group', 'Lester, Woodard and Mitchell',
#        'Sanford, Davenport and Giles', 'Browning-Simon', 'Beck-Hendrix',
#        'Oconnell, Meza and Everett', 'Hoffman, Reed and Mcclain',
#        'Graham-Francis', 'Carpenter-Cook', 'Carter-Hancock',
#        'Singleton and Sons', 'Winters-Mendoza', 'Valentine LLC',
#        'Simon LLC', 'Mays-Mccormick', 'Patterson Inc',
#        'Manning, Hester and Arroyo', 'Greer and Sons', 'Watts-Donaldson',
#        'Tucker LLC', 'Giles Ltd', 'Simmons Group',
#        'Hinton, Chaney and Stokes', 'Santana-Duran', 'Sawyer PLC',
#        'Acosta, Petersen and Morrow', 'Mcgee Group', 'Adkins-Salinas',
#        'Herrera Group', 'Waters, Chase and Aguilar',
#        'Palmer, Barnes and Houston', 'Jordan Ltd', 'Glover and Sons',
#        'Huerta-Mclean', 'Anderson Ltd', 'Monroe PLC', 'Kaufman and Sons',
# ...

# %%
# Value_count : It is used to find the count of unique categories.
data.Company.value_counts()
# Out:
# Company
# Simon LLC                      2
# Rasmussen Group                1
# Knight, Abbott and Hubbard     1
# Parrish Ltd                    1
# Huynh and Sons                 1
#                               ..
# Mcgee Group                    1
# Acosta, Petersen and Morrow    1
# Sawyer PLC                     1
# Santana-Duran                  1
# Le, Nash and Cross             1
# Name: count, Length: 99, dtype: int64

# %%
# How to check missing values
data.isnull()
# Out:
#     Index  Customer Id  First Name  Last Name  Company   City  Country  \
# 0   False        False       False      False    False  False    False
# 1   False        False       False      False    False  False    False
# 2   False        False       False      False    False  False    False
# 3   False        False       False      False    False  False    False
# 4   False        False       False      False    False  False    False
# ..    ...          ...         ...        ...      ...    ...      ...
# 95  False        False       False      False    False  False    False
# 96  False        False       False      False    False  False    False
# 97  False        False       False      False    False  False    False
# 98  False        False       False      False    False  False    False
# 99  False        False       False      False    False  False    False
#
#     Phone 1  Phone 2  Email  Subscription Date  Website
# 0     False    False  False              False    False
# ...

# %%
# How to check missing values
data.isnull().sum()
# Out:
# Index                0
# Customer Id          0
# First Name           0
# Last Name            0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Phone 2              0
# Email                0
# Subscription Date    0
# Website              0
# dtype: int64

# %%
# How to create copy of data
data1=data.copy()

# %%
data1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
data.Country.unique()
# Out:
# array(['Chile', 'Djibouti', 'Antigua and Barbuda', 'Dominican Republic',
#        'Slovakia (Slovak Republic)', 'Bosnia and Herzegovina',
#        'Pitcairn Islands', 'Bulgaria', 'Cyprus', 'Timor-Leste',
#        'Guernsey', 'Vietnam', 'Togo', 'Sri Lanka', 'Singapore', 'Oman',
#        'Western Sahara', 'Mozambique',
#        'South Georgia and the South Sandwich Islands', 'French Polynesia',
#        'Malta', 'Netherlands', 'Paraguay',
#        "Lao People's Democratic Republic", 'Albania', 'Panama', 'Belarus',
#        'Switzerland', 'Saint Vincent and the Grenadines', 'Tanzania',
#        'Zimbabwe', 'Denmark', 'Liechtenstein', 'United States of America',
#        'Bahamas', 'Belize', 'Uruguay', 'Solomon Islands', 'Montenegro',
#        'Poland', 'Burkina Faso', 'Bolivia', 'Monaco', 'Palau',
#        'Uzbekistan', 'Ghana', 'United Arab Emirates', 'Canada', 'Algeria',
#        'Swaziland', 'Madagascar', 'Ecuador', 'Palestinian Territory',
# ...

# %%
data.City.unique()
# Out:
# array(['East Leonard', 'East Jimmychester', 'Isabelborough', 'Bensonview',
#        'West Priscilla', 'Chavezborough', 'Lake Ana', 'Kimport',
#        'Robersonstad', 'Elaineberg', 'Shannonville', 'East Andrea',
#        'South Joannamouth', 'Jodyberg', 'Burchbury', 'Desireeshire',
#        'West Adriennestad', 'Lake Leslie', 'Harmonview', 'Jamesshire',
#        'East Carly', 'South Alvin', 'Brittanyview', 'Veronicamouth',
#        'Bryanville', 'Kaitlyntown', 'Michealshire', 'South Marissatown',
#        'Acevedoville', 'North Harold', 'West Samuel', 'Cunninghamborough',
#        'Port Annatown', 'New Kaitlyn', 'West Marthaburgh', 'East Teresa',
#        'South Hunter', 'South Walter', 'Poolefurt', 'West John',
#        'West Darius', 'North Jimstad', 'East Rebekahborough',
#        'North Drew', 'Lake Lindaburgh', 'Gwendolynview', 'Zimmermanland',
#        'North Kerriton', 'North Eileenville', 'Port Sergiofort',
# ...

# %%
data.City.value_counts()
# Out:
# City
# East Leonard         1
# South Julia          1
# Skinnerport          1
# East Summerstad      1
# New Jasmineshire     1
#                     ..
# West Samuel          1
# North Harold         1
# Acevedoville         1
# South Marissatown    1
# Judymouth            1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# # Create New Column

# %%
data1['Customerid']=data1["City"]+data1["Country"]

# %%
data1.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website', 'Customerid'],
#       dtype='object')

# %%
data1
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
data1["Company"]="Chile"

# %%
data1
# Out:
#     Index      Customer Id First Name Last Name Company               City  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter   Chile       East Leonard
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano   Chile  East Jimmychester
# 2       3  6F94879bDAfE5a6        Roy     Berry   Chile      Isabelborough
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen   Chile         Bensonview
# 4       5  053d585Ab6b3159     Joanna    Bender   Chile     West Priscilla
# ..    ...              ...        ...       ...     ...                ...
# 95     96  cb8E23e48d22Eae       Karl     Greer   Chile       East Richard
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson   Chile       New Bradview
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra   Chile         Ortegaland
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer   Chile    Lake Elijahview
# 99    100  2354a0E336A91A1   Clarence    Haynes   Chile          Judymouth
#
#                        Country                 Phone 1  \
# ...

# %%
data1.head(2)
# Out:
#    Index      Customer Id First Name Last Name Company               City  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter   Chile       East Leonard
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano   Chile  East Jimmychester
#
#     Country       Phone 1           Phone 2                     Email  \
# 0     Chile  229.077.5154  397.884.0519x718  zunigavanessa@smith.info
# 1  Djibouti    5153435776  686-620-1820x944           vmata@colon.com
#
#   Subscription Date                     Website                 Customerid
# 0        2020-08-24  http://www.stephenson.com/          East LeonardChile
# 1        2021-04-23       http://www.hobbs.com/  East JimmychesterDjibouti

# %% [markdown]
# # Remove column

# %%
# Axis 1 is used when we do any column manipulation
data1.drop("City",axis=1)
# Out:
#     Index      Customer Id First Name Last Name Company  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter   Chile
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano   Chile
# 2       3  6F94879bDAfE5a6        Roy     Berry   Chile
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen   Chile
# 4       5  053d585Ab6b3159     Joanna    Bender   Chile
# ..    ...              ...        ...       ...     ...
# 95     96  cb8E23e48d22Eae       Karl     Greer   Chile
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson   Chile
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra   Chile
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer   Chile
# 99    100  2354a0E336A91A1   Clarence    Haynes   Chile
#
#                        Country                 Phone 1  \
# 0                        Chile            229.077.5154
# 1                     Djibouti              5153435776
# 2          Antigua and Barbuda         +1-539-402-0259
# 3           Dominican Republic  001-808-617-6467x12895
# ...

# %%
data1.drop("City",axis=1,inplace=True)

# %%
data1.head()
# Out:
#    Index      Customer Id First Name Last Name Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter   Chile
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano   Chile
# 2      3  6F94879bDAfE5a6        Roy     Berry   Chile
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen   Chile
# 4      5  053d585Ab6b3159     Joanna    Bender   Chile
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# 3          Dominican Republic  001-808-617-6467x12895        +1-813-324-8756
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146  001-199-446-3860x3486
#
#                          Email Subscription Date                      Website  \
# 0     zunigavanessa@smith.info        2020-08-24   http://www.stephenson.com/
# ...

# %%
# drop Company and Country Columns
data1.drop(["Company","Country"],axis=1,inplace=True)

# %%
data1.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Phone 1', 'Phone 2',
#        'Email', 'Subscription Date', 'Website', 'Customerid'],
#       dtype='object')

# %% [markdown]
# # Type Casting

# %%
# Type casting is used to convert one data type into other
data1.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# Customerid           object
# dtype: object

# %%
# Tyepe casting will not work when there are missing values
